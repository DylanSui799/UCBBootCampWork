# %%
# %matplotlib inline

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set x axis and variables
x = np.arange(0, 10, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
# Plot the data with labels
plt.plot(x, y1)
plt.plot(x, y2)

plt.show()

# %%
# Draw a horizontal line with 0.25 transparency
plt.hlines(0, 0, 10, alpha=0.25)

plt.show()

# %%
# Assign plots to tuples that stores result of plot

# Each point on the sine chart is marked by a blue circle
plt.plot(x, y1, marker ='x', color='green', label="Sine")
# Each point on the cosine chart is marked by a red triangle
plt.plot(x, y2, marker='^', color='red', label="Cosine")

# Draw a horizontal line with 0.25 transparency
plt.hlines(0, 0, 10, alpha=0.25)

plt.legend(loc="best")

plt.savefig("../Images/test.png")

# plt.show()

# %%
# Adds a legend and sets its location to the lower right
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Draw a horizontal line with 0.25 transparency
plt.hlines(0, 0, 10, alpha=0.25)

# Plot the data with labels
plt.plot(x, y1, marker ='o', color='blue', label="Sine")
# Each point on the cosine chart is marked by a red triangle
plt.plot(x, y2, marker='^', color='red', label="Cosine")

# Add legend
plt.legend(loc="lower right")

# Saves an image of our chart so that we can view it in a folder
plt.savefig("../Images/lineConfig.png")
plt.show()
