# %% [markdown]
# # Nearest Restaurants in Barcelona

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Import the API key
from config_key import geoapify_key

# %%
# Load the restaurant ethnicities into a DataFrame
types_df = pd.read_csv("../Resources/ethnicities.csv")

# Display sample data
types_df.head()
# Out:
#   ethnicity
# 0   italian
# 1   chinese
# 2   mexican
# 3  japanese
# 4  american

# %%
# Set up additional columns to hold information
types_df["name"] = ""
types_df["address"] = ""
types_df["distance"] = ""

# Display sample data
types_df.head()
# Out:
#   ethnicity name address distance
# 0   italian
# 1   chinese
# 2   mexican
# 3  japanese
# 4  american

# %% [markdown]
# Find the closest restaurant of each type to the Plaça de Catalunya in Barcelona, Spain
#
# * Latitude: 41.38753134515075
#
# * Longitude: 2.1700662596820544

# %%
# Set the geographical coordinates
latitude = 41.38753134515075
longitude = 2.1700662596820544

# Set the parameters for the type of search
limit = 20
radius = 800
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"

# set up a parameters dictionary
params = {
    "filter":filters,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Print a message to follow up the restaurant search
print("Starting restaurant search")

# Iterate through the types_df DataFrame
for index, row in types_df.iterrows():

    # Get the ethnicity type from the current DataFrame's row
    ethnicity = types_df.loc[index, "ethnicity"]
    # Add the current ethnicity type to the parameters
    params["categories"] = f"catering.restaurant.{ethnicity}"

    # Make an API request using the params dictionary
    restaurant = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    restaurant = restaurant.json()

    # Grab the first restaurant from the results and store the details in the DataFrame
    try:
        types_df.loc[index, "name"] = restaurant["features"][0]["properties"]["name"]
        types_df.loc[index, "address"] = restaurant["features"][0]["properties"]["address_line2"]
        types_df.loc[index, "distance"] = int(restaurant["features"][0]["properties"]["distance"])
    except (KeyError, IndexError):
        # If no restaurant is found, set the restaurant name as "No restaurant found".
        types_df.loc[index, "name"] = "No restaurant found"
        # Set the distance column value to np.nan to allow sorting values
        types_df.loc[index, "distance"] = np.nan

    # Log the search results
    print(f"nearest {types_df.loc[index, 'ethnicity']} restaurant: {types_df.loc[index, 'name']}")

# Display sample data
types_df
# Out:
# Starting restaurant search
# nearest italian restaurant: Vapiano
# nearest chinese restaurant: Dim Sum House
# nearest mexican restaurant: Rosa Negra
# nearest japanese restaurant: Kaitensushi He
# nearest american restaurant: Hard Rock Cafe
# nearest indian restaurant: Surya
# nearest asian restaurant: Japonés Machiroku
# nearest french restaurant: Restaurant La Taverneta Barcelona
# nearest german restaurant: Alt Heidelberg
# nearest thai restaurant: Thai Barcelona
# nearest greek restaurant: No restaurant found
# nearest tex-mex restaurant: No restaurant found
# nearest vietnamese restaurant: Bun Bo Gótico
# nearest turkish restaurant: Aromas de Turquía redtaurant
# nearest korean restaurant: Restaurant Corea
# nearest spanish restaurant: Fresc Co
# nearest lebanese restaurant: La Marimba
# nearest indonesian restaurant: Betawi
# nearest portuguese restaurant: No restaurant found
# nearest arab restaurant: Albawadi
# nearest russian restaurant: No restaurant found
# nearest filipino restaurant: Filmanila
# nearest african restaurant: No restaurant found
# nearest malaysian restaurant: No restaurant found
# nearest caribbean restaurant: No restaurant found
# nearest peruvian restaurant: Riko's Braseria - Restaurante
# nearest bavarian restaurant: No restaurant found
# nearest brazilian restaurant: No restaurant found
# nearest persian restaurant: No restaurant found
# nearest argentinian restaurant: Gaucho's
# nearest oriental restaurant: No restaurant found
# nearest balkan restaurant: No restaurant found
# nearest moroccan restaurant: No restaurant found
# nearest ethiopian restaurant: No restaurant found
# nearest taiwanese restaurant: No restaurant found
# nearest latin_american restaurant: No restaurant found
# nearest hawaiian restaurant: No restaurant found
# nearest irish restaurant: No restaurant found
# nearest austrian restaurant: No restaurant found
# nearest croatian restaurant: No restaurant found
# nearest danish restaurant: No restaurant found
# nearest bolivian restaurant: No restaurant found
# nearest hungarian restaurant: No restaurant found
# nearest european restaurant: No restaurant found
# nearest jamaican restaurant: No restaurant found
# nearest cuban restaurant: No restaurant found
# nearest uzbek restaurant: No restaurant found
# nearest nepalese restaurant: Veggie Garden
# nearest czech restaurant: No restaurant found
# nearest syrian restaurant: No restaurant found
# nearest afghan restaurant: No restaurant found
# nearest malay restaurant: No restaurant found
# nearest belgian restaurant: No restaurant found
# nearest ukrainian restaurant: No restaurant found
# nearest swedish restaurant: No restaurant found
# nearest pakistani restaurant: No restaurant found
#          ethnicity                               name  \
# 0          italian                            Vapiano
# 1          chinese                      Dim Sum House
# 2          mexican                         Rosa Negra
# 3         japanese                     Kaitensushi He
# 4         american                     Hard Rock Cafe
# 5           indian                              Surya
# 6            asian                  Japonés Machiroku
# 7           french  Restaurant La Taverneta Barcelona
# 8           german                     Alt Heidelberg
# 9             thai                     Thai Barcelona
# 10           greek                No restaurant found
# 11         tex-mex                No restaurant found
# 12      vietnamese                      Bun Bo Gótico
# 13         turkish       Aromas de Turquía redtaurant
# 14          korean                   Restaurant Corea
# 15         spanish                           Fresc Co
# 16        lebanese                         La Marimba
# 17      indonesian                             Betawi
# 18      portuguese                No restaurant found
# 19            arab                           Albawadi
# 20         russian                No restaurant found
# 21        filipino                          Filmanila
# 22         african                No restaurant found
# 23       malaysian                No restaurant found
# 24       caribbean                No restaurant found
# 25        peruvian      Riko's Braseria - Restaurante
# 26        bavarian                No restaurant found
# 27       brazilian                No restaurant found
# 28         persian                No restaurant found
# 29     argentinian                           Gaucho's
# 30        oriental                No restaurant found
# 31          balkan                No restaurant found
# 32        moroccan                No restaurant found
# 33       ethiopian                No restaurant found
# 34       taiwanese                No restaurant found
# 35  latin_american                No restaurant found
# 36        hawaiian                No restaurant found
# 37           irish                No restaurant found
# 38        austrian                No restaurant found
# 39        croatian                No restaurant found
# 40          danish                No restaurant found
# 41        bolivian                No restaurant found
# 42       hungarian                No restaurant found
# 43        european                No restaurant found
# 44        jamaican                No restaurant found
# 45           cuban                No restaurant found
# 46           uzbek                No restaurant found
# 47        nepalese                      Veggie Garden
# 48           czech                No restaurant found
# 49          syrian                No restaurant found
# 50          afghan                No restaurant found
# 51           malay                No restaurant found
# 52         belgian                No restaurant found
# 53       ukrainian                No restaurant found
# 54         swedish                No restaurant found
# 55       pakistani                No restaurant found
#
#                                               address distance
# 0   Gran Via de les Corts Catalanes, 08001 Barcelo...      234
# 1        Carrer de Bergara, 7, 08001 Barcelona, Spain      226
# 2   Carrer de Sant Pere Més Baix, 5, 08003 Barcelo...      477
# 3    Carrer de Pau Claris, 72, 08010 Barcelona, Spain      248
# 4         Plaça Catalunya, 21, 08002 Barcelona, Spain      184
# 5    Carrer de Pau Claris, 92, 08010 Barcelona, Spain      303
# 6     Carrer de les Moles, 21, 08002 Barcelona, Spain      239
# 7   Carrer de Francesc Pujols, 3, 08002 Barcelona,...      425
# 8   Ronda de la Universitat, 5, 08007 Barcelona, S...      430
# 9   Carrer de la Diputació, 273, 08001 Barcelona, ...      442
# 10                                                         NaN
# 11                                                         NaN
# 12  Carrer dels Sagristans, 3, 08002 Barcelona, Spain      495
# 13                  La Rambla, 08001 Barcelona, Spain      296
# 14         Ronda de Sant Pere, 08001 Barcelona, Spain      460
# 15         Carrer de Casp, 30, 08001 Barcelona, Spain      291
# 16       Carrer de Pau Claris, 08001 Barcelona, Spain      660
# 17       Carrer de Montsió, 6, 08002 Barcelona, Spain      373
# 18                                                         NaN
# 19               Via Laietana, 08001 Barcelona, Spain      301
# 20                                                         NaN
# 21  Carrer de les Ramelleres, 3, 08001 Barcelona, ...      416
# 22                                                         NaN
# 23                                                         NaN
# 24                                                         NaN
# 25  Carrer de Roger de Llúria, 54, 08009 Barcelona...      611
# 26                                                         NaN
# 27                                                         NaN
# 28                                                         NaN
# 29        Carrer d'Aragó, 235, 08001 Barcelona, Spain      721
# 30                                                         NaN
# 31                                                         NaN
# 32                                                         NaN
# 33                                                         NaN
# 34                                                         NaN
# 35                                                         NaN
# 36                                                         NaN
# 37                                                         NaN
# 38                                                         NaN
# 39                                                         NaN
# 40                                                         NaN
# 41                                                         NaN
# 42                                                         NaN
# 43                                                         NaN
# 44                                                         NaN
# 45                                                         NaN
# 46                                                         NaN
# 47      Carrer dels Àngels, 3, 08001 Barcelona, Spain      608
# 48                                                         NaN
# 49                                                         NaN
# 50                                                         NaN
# 51                                                         NaN
# 52                                                         NaN
# 53                                                         NaN
# 54                                                         NaN
# 55                                                         NaN

# %%
# Sort restuls by distance
types_df = types_df.sort_values(by=["distance"])

# Display the top 10 nearest restaurants
types_df.head(10)
# Out:
#      ethnicity                          name  \
# 4     american                Hard Rock Cafe
# 1      chinese                 Dim Sum House
# 0      italian                       Vapiano
# 6        asian             Japonés Machiroku
# 3     japanese                Kaitensushi He
# 15     spanish                      Fresc Co
# 13     turkish  Aromas de Turquía redtaurant
# 19        arab                      Albawadi
# 5       indian                         Surya
# 17  indonesian                        Betawi
#
#                                               address distance
# 4         Plaça Catalunya, 21, 08002 Barcelona, Spain      184
# 1        Carrer de Bergara, 7, 08001 Barcelona, Spain      226
# 0   Gran Via de les Corts Catalanes, 08001 Barcelo...      234
# 6     Carrer de les Moles, 21, 08002 Barcelona, Spain      239
# 3    Carrer de Pau Claris, 72, 08010 Barcelona, Spain      248
# 15         Carrer de Casp, 30, 08001 Barcelona, Spain      291
# 13                  La Rambla, 08001 Barcelona, Spain      296
# 19               Via Laietana, 08001 Barcelona, Spain      301
# 5    Carrer de Pau Claris, 92, 08010 Barcelona, Spain      303
# 17       Carrer de Montsió, 6, 08002 Barcelona, Spain      373
