# %%
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
file = Path("Resources/Seattle_Housing_Cost_Burden.csv")
file_df = pd.read_csv(file)
file_df.head()
# Out:
#    YEAR         AMI    RACE   TENURE       AGE  TOTAL  BURDEN30  BURDEN3050  \
# 0  2006  Above 120%  Native  Renters   Seniors      0         0           0
# 1  2006  Above 120%  Native  Renters  Children      0         0           0
# 2  2006  Above 120%   Asian      All       All  33864      5655        4488
# 3  2006  Above 120%   Asian      All   Seniors   1718       517         360
# 4  2006  Above 120%   Asian      All  Children   3703       504         436
#
#    BURDEN50  NODATA  NOBURDEN  PERCENT30  PERCENT3050  PERCENT50  \
# 0         0       0         0        NaN          NaN        NaN
# 1         0       0         0        NaN          NaN        NaN
# 2      1167       0     28209   0.166991     0.132530   0.034461
# 3       157       0      1201   0.300931     0.209546   0.091385
# 4        68       0      3199   0.136106     0.117742   0.018363
#
#    PERCENT_NODATA  PERCENT_NOBURDEN         INCOME        COSTS  ObjectId
# 0             NaN               NaN            NaN          NaN         1
# 1             NaN               NaN            NaN          NaN         2
# 2             0.0          0.833009  146287.706591  2473.832373         3
# 3             0.0          0.699069  147017.508731  2508.574904         4
# 4             0.0          0.863894  161444.756144  2873.532237         5

# %%
# Check the data types.
file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4212 entries, 0 to 4211
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              4212 non-null   int64
#  1   AMI               4212 non-null   object
#  2   RACE              4212 non-null   object
#  3   TENURE            4212 non-null   object
#  4   AGE               4212 non-null   object
#  5   TOTAL             4212 non-null   int64
#  6   BURDEN30          4212 non-null   int64
#  7   BURDEN3050        4212 non-null   int64
#  8   BURDEN50          4212 non-null   int64
#  9   NODATA            4212 non-null   int64
#  10  NOBURDEN          4212 non-null   int64
#  11  PERCENT30         3994 non-null   float64
#  12  PERCENT3050       3994 non-null   float64
#  13  PERCENT50         3994 non-null   float64
#  14  PERCENT_NODATA    3994 non-null   float64
#  15  PERCENT_NOBURDEN  3994 non-null   float64
#  16  INCOME            3994 non-null   float64
#  17  COSTS             2652 non-null   float64
#  18  ObjectId          4212 non-null   int64
# dtypes: float64(7), int64(8), object(4)
# memory usage: 625.3+ KB

# %%
file_df = file_df.dropna()

# %%
# Use Map to format all the columns
file_df["INCOME"] = file_df["INCOME"].map("${:,.2f}".format)
file_df["COSTS"] = file_df["COSTS"].map("${:,.2f}".format)
file_df["PERCENT30"] = (file_df["PERCENT30"]*100).map("{:.1f}%".format)
file_df["PERCENT3050"] = (file_df["PERCENT3050"]*100).map("{:.1f}%".format)
file_df["PERCENT50"] = (file_df["PERCENT50"]*100).map("{:.1f}%".format)
file_df["PERCENT_NODATA"] = (file_df["PERCENT_NODATA"]*100).map("{:.1f}%".format)
file_df["PERCENT_NOBURDEN"] = (file_df["PERCENT_NOBURDEN"]*100).map("{:.1f}%".format)
file_df["TOTAL"] = file_df["TOTAL"].map("{:,}".format)
file_df.head()
# Out:
#    YEAR         AMI   RACE  TENURE       AGE   TOTAL  BURDEN30  BURDEN3050  \
# 2  2006  Above 120%  Asian     All       All  33,864      5655        4488
# 3  2006  Above 120%  Asian     All   Seniors   1,718       517         360
# 4  2006  Above 120%  Asian     All  Children   3,703       504         436
# 5  2006  Above 120%  Asian  Owners       All  27,066      5580        4413
# 6  2006  Above 120%  Asian  Owners   Seniors   1,562       517         360
#
#    BURDEN50  NODATA  NOBURDEN PERCENT30 PERCENT3050 PERCENT50 PERCENT_NODATA  \
# 2      1167       0     28209     16.7%       13.3%      3.4%           0.0%
# 3       157       0      1201     30.1%       21.0%      9.1%           0.0%
# 4        68       0      3199     13.6%       11.8%      1.8%           0.0%
# 5      1167       0     21486     20.6%       16.3%      4.3%           0.0%
# 6       157       0      1045     33.1%       23.0%     10.1%           0.0%
#
#   PERCENT_NOBURDEN       INCOME      COSTS  ObjectId
# 2            83.3%  $146,287.71  $2,473.83         3
# 3            69.9%  $147,017.51  $2,508.57         4
# 4            86.4%  $161,444.76  $2,873.53         5
# 5            79.4%  $152,446.17  $2,473.83         6
# 6            66.9%  $152,593.91  $2,508.57         7

# %%
# Mapping has changed the data types of the columns to strings
file_df.dtypes
# Out:
# YEAR                 int64
# AMI                 object
# RACE                object
# TENURE              object
# AGE                 object
# TOTAL               object
# BURDEN30             int64
# BURDEN3050           int64
# BURDEN50             int64
# NODATA               int64
# NOBURDEN             int64
# PERCENT30           object
# PERCENT3050         object
# PERCENT50           object
# PERCENT_NODATA      object
# PERCENT_NOBURDEN    object
# INCOME              object
# COSTS               object
# ObjectId             int64
# dtype: object

# %%
file_df["PERCENT_NOBURDEN"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 file_df["PERCENT_NOBURDEN"].mean()
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/generic.py:11984, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11977 def mean(
#   11978     self,
#   11979     axis: Axis | None = 0,
#    (...)
#   11982     **kwargs,
#   11983 ) -> Series | float:
# > 11984     return self._stat_function(
#   11985         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11986     )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/generic.py:11941, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11937 nv.validate_func(name, (), kwargs)
#   11939 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11941 return self._reduce(
#   11942     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11943 )
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6124     # GH#47500 - change to TypeError to match other methods
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1690 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1691     if isinstance(x, str):
#    1692         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694     try:
#    1695         x = float(x)
#
# TypeError: Could not convert string '83.3%69.9%86.4%79.4%66.9%83.4%89.3%71.0%92.2%86.3%71.0%91.5%61.2%61.2%55.0%65.1%69.5%59.1%63.1%63.2%56.8%66.6%71.6%60.3%48.9%41.3%47.0%57.5%49.9%62.6%59.7%100.0%64.0%73.7%100.0%51.4%57.0%52.2%63.5%56.4%50.0%56.4%55.9%55.9%42.7%60.8%64.5